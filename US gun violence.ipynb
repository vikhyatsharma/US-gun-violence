# %%
import plotly.graph_objects as go
from plotly.offline import iplot
from IPython.display import display
from ipywidgets import *

import pandas as pd

mapbox_access_token = 'pk.eyJ1IjoiZ2hjYXJuZWlybyIsImEiOiJjazBmOXNjNmswcWcyM2JxZXhjNzc2eDBkIn0.L4pHZaHSpa4pQL-fML9i5w'

df = pd.read_csv('file://localhost/C:/Users/LenovO/Desktop/final project 2/all_years.csv')
df['locations_date'] = df.date.astype(str)
df['city_or_county'] = df.city_or_county.astype(str)
df['n_killed'] = df.n_killed.astype(str)     
df['n_injured'] = df.n_injured.astype(str)
df['incident_characteristics'] = df.incident_characteristics.astype(str)
site_lat = df.latitude
site_lon = df.longitude
df['n_guns_involved'] = df.n_guns_involved.astype(str)
df['participant_age_group'] = df.participant_age_group.astype(str)


dataayears = [
    go.Scattermapbox(
        lat=site_lat,
        lon=site_lon,
        mode='markers',
        marker=dict(
            size=2,
            color='rgb(255, 215, 0)',
            opacity=0.7
        ),
        text="Date: " + df['locations_date'] + "<br />" + "n_killed:  "+ df['n_killed'] + "<br />" + "n_injured: " + df['n_injured'] + "<br />"  + "age group: " + df['participant_age_group'] + "<br />" + "city_or_county: " + df['city_or_county']       ,
        hoverinfo='text',
        name="casualties"
    )]


layoutayears = go.Layout(
    title='US gun violence 2014-2017',
    autosize=True,
    hovermode='closest',
    showlegend=True,
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=38,
            lon=-94
        ),
        pitch=0,
        zoom=3,
        style='dark'
    ),
)

figayears = dict(data=dataayears, layout=layoutayears)
